# %% [markdown]
# <!-- ###CAR DEKHO QUESTION###  -->

# %% [markdown]
# # CAR DEKHO DATASET {EDA} :-

# %% [markdown]
# # Import Libraries & Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\b2xbt\Downloads\CAR DETAILS FROM CAR DEKHO.csv")

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.sample()
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 3982  Chevrolet Cruze LT  2012         380000      90000  Diesel  Individual
#
#      transmission                 owner
# 3982       Manual  Fourth & Above Owner

# %% [markdown]
# # HIGHEST KM DRIVEN CAR?

# %%
df['km_driven'].value_counts()
# Out:
# km_driven
# 70000     236
# 80000     228
# 50000     222
# 120000    220
# 60000     215
#          ...
# 19107       1
# 32077       1
# 6480        1
# 118400      1
# 112198      1
# Name: count, Length: 770, dtype: int64

# %%
df['km_driven'].max()
# Out:
# 806599

# %%
df[df['km_driven']==df['km_driven'].max()]
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 1243  Maruti Swift VXI BSIII  2009         250000     806599  Petrol
#
#      seller_type transmission        owner
# 1243      Dealer       Manual  First Owner

# %% [markdown]
# # Name the top 5 costly cars?

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000     162
# 250000     125
# 350000     122
# 550000     107
# 600000     103
#           ...
# 2100000      1
# 828999       1
# 1119000      1
# 746000       1
# 865000       1
# Name: count, Length: 445, dtype: int64

# %%
df.sort_values(by='selling_price',).tail(5)
# Out:
#                                                    name  year  selling_price  \
# 1023                            BMW X5 xDrive 30d xLine  2019        4950000
# 2239                            BMW X5 xDrive 30d xLine  2019        4950000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 1023      30000  Diesel      Dealer    Automatic  First Owner
# 2239      30000  Diesel      Dealer    Automatic  First Owner
# 3969      77350  Diesel      Dealer    Automatic  First Owner
# 89         6500  Diesel      Dealer    Automatic  First Owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %% [markdown]
# # Name the cheapest cars and how much it driven?

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000     162
# 250000     125
# 350000     122
# 550000     107
# 600000     103
#           ...
# 2100000      1
# 828999       1
# 1119000      1
# 746000       1
# 865000       1
# Name: count, Length: 445, dtype: int64

# %%
df.sort_values(by='selling_price').head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
# 2495      Ford Ikon 1.4 ZXi  2000          22000      42743  Petrol
# 2444          Maruti 800 EX  2004          30000      60000  Petrol
# 3206       OpelCorsa 1.4 GL  2002          35000     100000  Petrol
# 2849     Tata Nano Std BSII  2009          35000      50000  Petrol
#
#      seller_type transmission         owner
# 2662  Individual       Manual  Second Owner
# 2495      Dealer       Manual   Third Owner
# 2444  Individual       Manual   Third Owner
# 3206  Individual       Manual   Third Owner
# 2849  Individual       Manual   Third Owner

# %% [markdown]
# # Avg Selling of cars?

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# # Name the costly cars and how much it driven,with there selling price?

# %%
df.value_counts()
# Out:
# name                              year  selling_price  km_driven  fuel    seller_type       transmission  owner
# Renault Duster 85PS Diesel RxL    2013  450000         1000       Diesel  Dealer            Manual        Second Owner    12
# Hyundai Verna 1.6 VTVT SX         2015  760000         55340      Petrol  Trustmark Dealer  Manual        First Owner     12
# Hyundai Santro GS                 2005  80000          56580      Petrol  Dealer            Manual        First Owner     12
# Maruti S-Cross Zeta DDiS 200 SH   2015  750000         45974      Diesel  Trustmark Dealer  Manual        First Owner     12
# Maruti SX4 Vxi BSIV               2012  225000         110000     Petrol  Individual        Manual        Second Owner    12
#                                                                                                                           ..
# ...

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000     162
# 250000     125
# 350000     122
# 550000     107
# 600000     103
#           ...
# 2100000      1
# 828999       1
# 1119000      1
# 746000       1
# 865000       1
# Name: count, Length: 445, dtype: int64

# %%
df['selling_price'].max()
# Out:
# 8900000

# %%
df[df['selling_price']==df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %% [markdown]
# # Name the Costly cars of Automatic transmission with price?

# %%
automatic_df = df[df['transmission'] == 'Automatic']
automatic_df[automatic_df['selling_price']==automatic_df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %% [markdown]
# # Give car details based on year input?

# %%
df['year'].value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %%
# ----------------------------------------------------------------------


# Q-8: Give car details based on selling price input, ex, car details above 10lakh price?


# -----------------------------------------------------------------------

# %%
df[df['selling_price']>=1000000]
# Out:
#                                       name  year  selling_price  km_driven  \
# 12         Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25         Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 27             Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 29              Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# 30    Mercedes-Benz New C-Class 220 CDI AT  2013        1425000      59000
# ...                                    ...   ...            ...        ...
# 4302                    BMW 7 Series 730Ld  2006        1050000      30000
# 4304    Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4311               Toyota Camry Hybrid 2.5  2017        1900000      20118
# 4312                 Maruti Ertiga 1.5 VDI  2019        1000000      15000
# 4313    Ford Endeavour 2.2 Titanium AT 4X2  2019        2800000      10000
#
#         fuel seller_type transmission        owner
# ...

# %% [markdown]
# # 40Lac rs or above car details?

# %%
df[df['selling_price']>=4000000]
# Out:
#                                                    name  year  selling_price  \
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 101          Mercedes-Benz E-Class Exclusive E 200 BSIV  2018        4500000
# 539      Mercedes-Benz GL-Class 350 CDI Blue Efficiency  2014        4400000
# 555                             BMW X5 xDrive 30d xLine  2019        4950000
# 574                             BMW X5 xDrive 30d xLine  2019        4950000
# 593                             BMW X5 xDrive 30d xLine  2019        4950000
# 612                             BMW X5 xDrive 30d xLine  2019        4950000
# 731               Land Rover Discovery Sport TD4 HSE 7S  2018        4000000
# 900                             BMW X5 xDrive 30d xLine  2019        4950000
# 919                             BMW X5 xDrive 30d xLine  2019        4950000
# 963                                   Audi A5 Sportback  2020        4700000
# ...

# %%
df[df['selling_price']>=4000000].shape
# Out:
# (26, 8)

# %% [markdown]
# #  Give car details based on Brand name?

# %%
df[df['name']=='BMW 5 Series 520d Luxury Line']
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 204   BMW 5 Series 520d Luxury Line  2017        2900000      40000  Diesel
# 3261  BMW 5 Series 520d Luxury Line  2017        2900000      40000  Diesel
# 3453  BMW 5 Series 520d Luxury Line  2018        4800000       9422  Diesel
# 3883  BMW 5 Series 520d Luxury Line  2019        4800000      12999  Diesel
#
#      seller_type transmission        owner
# 204   Individual    Automatic  First Owner
# 3261  Individual    Automatic  First Owner
# 3453  Individual    Automatic  First Owner
# 3883      Dealer    Automatic  First Owner

# %%
df.insert(0,'model',value = df['name'].apply(lambda x: x.split(' ')[0]))

# %% [markdown]
# # 2nd car details...........?

# %%
df[df['model']=='Jaguar']
# Out:
#        model                                  name  year  selling_price  \
# 29    Jaguar            Jaguar XF 2.2 Litre Luxury  2014        1964999
# 163   Jaguar       Jaguar XJ 5.0 L V8 Supercharged  2010        2550000
# 536   Jaguar         Jaguar XF 5.0 Litre V8 Petrol  2012        2050000
# 1417  Jaguar  Jaguar XF 3.0 Litre S Premium Luxury  2013        2000000
# 1532  Jaguar  Jaguar XF 3.0 Litre S Premium Luxury  2012        1800000
# 2175  Jaguar         Jaguar XF 5.0 Litre V8 Petrol  2012        2050000
#
#       km_driven    fuel seller_type transmission         owner
# 29        28000  Diesel      Dealer    Automatic   First Owner
# 163       40000  Petrol  Individual    Automatic  Second Owner
# 536       66363  Petrol      Dealer    Automatic  Second Owner
# 1417      64000  Diesel  Individual    Automatic  Second Owner
# 1532      50000  Diesel  Individual    Automatic  Second Owner
# 2175      66363  Petrol      Dealer    Automatic  Second Owner

# %% [markdown]
# #  Brand vs Fuel type car details?

# %%
df.sample()
# Out:
#         model                      name  year  selling_price  km_driven  \
# 1354  Hyundai  Hyundai Xcent 1.2 VTVT S  2019         660000       7000
#
#         fuel seller_type transmission         owner
# 1354  Petrol  Individual       Manual  Second Owner

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df[df['fuel']=='LPG']
# Out:
#           model                                       name  year  \
# 157      Maruti                     Maruti Wagon R DUO LPG  2014
# 222      Maruti  Maruti Omni LPG CARGO BSIII W IMMOBILISER  2009
# 483     Hyundai                 Hyundai EON LPG Magna Plus  2012
# 495     Hyundai          Hyundai Santro Xing GLS Audio LPG  2012
# 657     Hyundai                      Hyundai i10 Magna LPG  2013
# 703     Hyundai            Hyundai Santro Xing GL Plus LPG  2011
# 1355     Maruti                Maruti Wagon R LXI LPG BSIV  2012
# 1435    Hyundai                      Hyundai i10 Magna LPG  2014
# 1670     Maruti               Maruti Wagon R LXI DUO BS IV  2012
# 1699     Maruti                  Maruti Omni 5 Str STD LPG  1998
# 1702     Maruti                      Maruti 800 DUO AC LPG  2009
# 1810     Maruti               Maruti Wagon R LXI DUO BSIII  2009
# 1942     Maruti               Maruti Wagon R LXI DUO BSIII  2008
# ...

# %%
df[df['fuel']=='Petrol']
# Out:
#         model                          name  year  selling_price  km_driven  \
# 0      Maruti                 Maruti 800 AC  2007          60000      70000
# 1      Maruti      Maruti Wagon R LXI Minor  2007         135000      50000
# 3      Datsun        Datsun RediGO T Option  2017         250000      46000
# 5      Maruti          Maruti Alto LX BSIII  2007         140000     125000
# 6     Hyundai     Hyundai Xcent 1.2 Kappa S  2016         550000      25000
# ...       ...                           ...   ...            ...        ...
# 4326    Honda            Honda City 1.5 GXI  2005          65000     150000
# 4327     Tata                  Tata Nano XM  2015         190000      60000
# 4329     Tata  Tata Manza Aura Safire BS IV  2010         160000      60000
# 4337   Maruti           Maruti 800 AC BSIII  2009         110000      83000
# 4339  Renault              Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df[df['fuel']=='Diesel']
# Out:
#         model                                          name  year  \
# 2     Hyundai                          Hyundai Verna 1.6 SX  2012
# 4       Honda                         Honda Amaze VX i-DTEC  2014
# 15    Hyundai                          Hyundai Verna 1.6 SX  2012
# 17      Honda                         Honda Amaze VX i-DTEC  2014
# 27    Hyundai                   Hyundai Venue SX Opt Diesel  2019
# ...       ...                                           ...   ...
# 4333   Maruti                               Maruti Ritz VDi  2012
# 4334   Toyota  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012
# 4335  Hyundai           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014
# 4336  Hyundai                    Hyundai i20 Magna 1.4 CRDi  2014
# 4338  Hyundai              Hyundai Creta 1.6 CRDi SX Option  2016
#
#       selling_price  km_driven    fuel seller_type transmission         owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# ...

# %%
df[df['fuel']=='CNG']
# Out:
#           model                                    name  year  selling_price  \
# 9        Maruti                Maruti Celerio Green VXI  2017         365000
# 22       Maruti                Maruti Celerio Green VXI  2017         365000
# 176      Maruti                 Maruti Alto K10 LXI CNG  2020         282000
# 351        Tata             Tata Indigo CS Emax CNG GLX  2014         185000
# 352      Maruti  Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999
# 361     Hyundai             Hyundai Santro Xing GLS CNG  2010         130000
# 664     Hyundai         Hyundai Santro Xing GL PLUS CNG  2007          90000
# 712      Maruti                   Maruti Ertiga VXI CNG  2013         525000
# 824      Maruti                 Maruti Alto 800 CNG LXI  2012         170000
# 863     Hyundai                  Hyundai Accent GLE CNG  2009         160000
# 1138     Maruti                  Maruti Wagon R LXI CNG  2013         250000
# ...

# %% [markdown]
# # Owner vs fuel vs year selling price?

# %%
df[df['owner']=='Third Owner']
# Out:
#          model                                  name  year  selling_price  \
# 44        Audi        Audi Q7 35 TDI Quattro Premium  2009        1250000
# 51     Hyundai               Hyundai Santro Xing GLS  2009         150000
# 74      Toyota   Toyota Innova 2.5 V Diesel 8-seater  2009         500000
# 76      Maruti                  Maruti Swift 1.3 VXi  2006         130000
# 82     Hyundai                      Hyundai Getz GLS  2005          80000
# ...        ...                                   ...   ...            ...
# 4276      Ford           Ford Fiesta 1.6 ZXi Duratec  2009         233000
# 4288    Maruti                  Maruti Alto LX BSIII  2008         110000
# 4307  Mahindra                      Mahindra Xylo H4  2019         599000
# 4326     Honda                    Honda City 1.5 GXI  2005          65000
# 4331      Ford  Ford EcoSport 1.5 TDCi Titanium BSIV  2015         530000
#
#       km_driven    fuel seller_type transmission        owner
# ...

# %% [markdown]
# # Fuel vs km_driven?

# %%
df[df['fuel']=='CNG']
# Out:
#           model                                    name  year  selling_price  \
# 9        Maruti                Maruti Celerio Green VXI  2017         365000
# 22       Maruti                Maruti Celerio Green VXI  2017         365000
# 176      Maruti                 Maruti Alto K10 LXI CNG  2020         282000
# 351        Tata             Tata Indigo CS Emax CNG GLX  2014         185000
# 352      Maruti  Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999
# 361     Hyundai             Hyundai Santro Xing GLS CNG  2010         130000
# 664     Hyundai         Hyundai Santro Xing GL PLUS CNG  2007          90000
# 712      Maruti                   Maruti Ertiga VXI CNG  2013         525000
# 824      Maruti                 Maruti Alto 800 CNG LXI  2012         170000
# 863     Hyundai                  Hyundai Accent GLE CNG  2009         160000
# 1138     Maruti                  Maruti Wagon R LXI CNG  2013         250000
# ...

# %% [markdown]
# **owner**

# %% [markdown]
# # DONE

# %% [markdown]
# # LINK 🔗
# https://www.linkedin.com/in/satnam13/ , https://github.com/Satnamsingh-SQL
