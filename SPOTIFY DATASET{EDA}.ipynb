# %% [markdown]
# <img src="https://martech.org/wp-content/uploads/2017/09/spotify-logo-1920x1080.jpg" width="400">
# <h1><center>Spotify Exploratory Data Analysis</center></h1>

# %% [markdown]
# <h1><center><u>Domain Knowledge</u></center></h1>
# <p>Music has always been an integral part of human culture, and in the digital age, platforms like
# Spotify have revolutionized how we discover, listen to, and interact with music. Spotify, one
# of the world's leading music streaming services, not only provides an extensive library of
# songs but also generates vast amounts of data related to music, artists, and user interactions.
# The Spotify dataset under consideration is a valuable collection of music-related information
# that encompasses a wide range of details about tracks, albums, and artists available on the
# platform. It is a rich source of data that has been made available to researchers, developers,
# and music enthusiasts for various purposes, including music analysis, recommendation
# system development, and the exploration of music trends.
# This dataset includes a diverse set of attributes, from fundamental information like track and
# artist names to more intricate features like audio characteristics (e.g., danceability, energy,
# valence), popularity metrics, and even copyright details. With nearly 10,000 entries, it
# provides a comprehensive snapshot of music on Spotify.
# Researchers and developers can leverage this dataset to gain insights into music trends, create
# advanced recommendation systems, analyze the impact of different musical attributes on
# popularity, and much more. Moreover, it offers a unique opportunity to explore the
# intersection of music and data science, unlocking new ways to understand and appreciate the
# art of sound.
# </p>
#
#
# <p>In this dataset, you will find a wealth of information waiting to be explored and analyzed,
# providing a glimpse into the vast world of music as experienced through the lens of Spotify's
# data.
# This introduction sets the stage for anyone interested in working with the Spotify dataset,
# highlighting its relevance and potential applications. Depending on the specific purpose of
# your work, you can delve deeper into the dataset to extract valuable insights and knowledge
# about the world of music as seen through Spotify's vast collection of songs and artists.
# </p>
#
# <p><b>Challenges faced</b>: Working with a Spotify dataset, like the one you described, can present
# several challenges, some of which are common in data analysis and others that are specific to
# music data. Here are some challenges you might encounter:</p>
#
#
# 1. **``Data Quality and Completeness``**: Ensuring the accuracy and completeness of the dataset can be a challenge. Missing or incorrect information about tracks, artists, or albums can affect the quality of your analysis.
# <br></br>
# 2. **``Data Consistency``**: Spotify data can come from various sources and may not always follow a consistent format. Inconsistent data can make it challenging to perform reliable analyses.
# <br></br>
# 3. **``Handling Missing Values``**: Dealing with missing values, especially in fields like "AlbumGenres," "Album Image URL," and "Track Preview URL," can require careful consideration. You may need to decide whether to impute missing data or exclude incomplete records.
# <br></br>
# 4. **``Data Privacy and Licensing``**: If you plan to use user-generated playlists or user-specific data, you must consider data privacy and obtain proper permissions and licenses. Ensuring compliance with Spotify's terms of use is crucial.
# <br></br>
# 5. **``Data Volume``**: With close to 10,000 entries and 35 columns, this dataset is relatively large. Managing and processing large datasets efficiently can be challenging, especially on less powerful hardware.
# <br></br>
# 6. **``Feature Selection``**: Determining which features are relevant for your analysis can be tricky. Some audio features might not be necessary for certain tasks, so selecting the right subset of features is essential.
# <br></br>
# 7. **``Audio Analysis``**: If you plan to use audio features, you might need to preprocess audio data, which involves tasks like audio segmentation, feature extraction, and handling different audio file formats.
# <br></br>
# 8. **``Categorical Data``**: Handling categorical data, such as artist names, album names, and genres, can be complex. One-hot encoding or other techniques may be needed for modeling.
# <br></br>
# 9. **``Data Exploration``**: Understanding the data's structure and relationships can be challenging. Visualizing the data and exploring correlations among features can be time-consuming.
# <br></br>
# 10. **``Bias and Subjectivity``**: Music preferences are subjective, and popularity measures can be biased. Be aware of potential biases when analyzing music-related data.
# <br></br>
# 11. **``Label and Copyright Information``**: Copyright and label details can be complex, and understanding the legal aspects of using this data is important. Additionally, this information may not always be up-to-date.
# <br></br>
# 12. **``Temporal Analysis``**: If your dataset includes a time series of music data, analyzing temporal trends and seasonality can be challenging but valuable.
# <br></br>
# 13. **``Data Updates``**: Spotify's music catalog and user-generated content are continually changing. Keeping your dataset up-to-date or re-collecting data for long-term projects can be demanding.
#
#
# Overcoming these challenges requires a combination of data cleaning, preprocessing,
# domain knowledge, and careful consideration of your specific analysis goals. Additionally,
# staying informed about the latest developments in Spotify's data offerings and data science
# techniques can help address these challenges effectively.

# %% [markdown]
# <h1><center><u>DATA UNDERSTANDING</u></center></h1>
#
# 1. **Dataset Overview**: Begin by obtaining basic information about your dataset, including its size, source, and any available documentation.
#
# 2. **Data Exploration**: Examine the first few rows of your dataset to get an initial sense of its structure and contents.
#
# 3. **Data Summary**: Compute summary statistics for numerical columns (e.g., mean, median, standard deviation) and count unique values for categorical columns.
#
# 4. **Data Visualization**: Create visual representations of the data to better understand its distribution and relationships. This can include histograms, bar charts, scatter plots, etc.
#
# 5. **Handling Missing Data**: Identify and address missing values. Decide whether to remove rows with missing data or impute missing values using techniques like mean imputation.
#
# 6. **Data Relationships**: Explore relationships between variables, such as correlations between numerical attributes or cross-tabulations for categorical data.
#
# 7. **Data Distribution**: Examine the distribution of data values for outliers, skewness, and potential data transformations.
#
# 8. **Domain-Specific Understanding**: If your data is from a specific domain, acquire domain knowledge to interpret and analyze it effectively.
#
# 9. **Data Sampling**: Consider taking a random sample of your data if it's extensive, which can make initial exploration more manageable.
#
# 10. **Documentation**: Maintain clear documentation or data dictionaries that explain the meaning of each column, data sources, and any data transformations or preprocessing steps applied.
#
#
# Data understanding is a critical preliminary step in data analysis and data science projects. It
# provides insights into the structure and characteristics of your dataset, helping you make
# informed decisions about data preprocessing, modeling, and analysis techniques.
#
# <br>
#
# </br>
#
# **This DataFrame represents a dataset of music-related information. Here's a brief description of the columns:**
#
#
# 1. **``Track URI``**: A unique identifier for each track on Spotify.
# 2. **``Track Name``**: The name/title of the track.
# 3. **``Artist URI(s)``**: Unique identifier(s) for the artist(s) of the track.
# 4. **``Artist Name(s)``**: The name(s) of the artist(s) associated with the track.
# 5. **``Album URI``**: Unique identifier for the album containing the track.
# 6. **``Album Name``**: The name of the album containing the track.
# 7. **``Album Artist URI(s)``**: Unique identifier(s) for the artist(s) of the album.
# 8. **``Album Artist Name(s)``**: The name(s) of the artist(s) of the album.
# 9. **``Album Release Date``**: The release date of the album. 10. Album Image URL: URL(s) to the album cover image.
# 11. **``Disc Number``**: The disc number of the track if part of a multi-disc release.
# 12. **``Track Number``**: The track number within the album.
# 13. **``Track Duration (ms)``**: The duration of the track in milliseconds.
# 14. **``Track Preview URL``**: URL to a preview or sample of the track.
# 15. **``Explicit``**: A boolean indicating whether the track contains explicit content.
# 16. **``Popularity``**: A measure of the track's popularity.
# 17. **``ISRC``**: International Standard Recording Code for the track.
# 18. **``Added By``**: Information about who added the track (possibly a user or source).
# 19. **``Added At``**: Date and time when the track was added.
# 20. **``Artist Genres``**: Genres associated with the artist(s).
# 21. **``Danceability``**: A measure of how suitable the track is for dancing.
# 22. **``Energy``**: A measure of the energy of the track.
# 23. **``Key``**: The key of the track(major vs minor music keys).
# 24. **``Loudness``**: A measure of the loudness of the track.
# 25. **``Mode``**: The modality of the track (major or minor).
# 26. **``Speechiness``**: A measure of the presence of spoken words in the track.
# 27. **``Acousticness``**: A measure of the track's acoustic characteristics.
# 28. **``Instrumentalness``**: A measure of the track's instrumental content.
# 29. **``Liveness``**: A measure of the presence of a live audience in the track.
# 30. **``Valence``**: A measure of the track's positivity.
# 31. **``Tempo``**: The tempo of the track.
# 32. **``Time Signature``**: The time signature of the track.
# 33. **``Album Genres``**: Genres associated with the album (though it appears to be mostly empty in this dataset).
# 34. **``Label``**: The record label associated with the track.
# 35. **``Copyrights``**: Copyright information associated with the track. This dataset appears to contain a wide range of information related to tracks, albums, and artists, including audio features that can be used for music analysis and recommendation systems.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Collection, Cleaning and Exploration

# %%
df=pd.read_csv('top_10000_1960-now.csv')
df.head()
# Out:
#                               Track URI  \
# 0  spotify:track:1XAZlnVtthcDZt2NI1Dtxo
# 1  spotify:track:6a8GbQIlV8HBUW3c6Uk9PH
# 2  spotify:track:70XtWbcVZcpaOddJftMcVi
# 3  spotify:track:1NXUWyPJk5kO6DQJ5t7bDu
# 4  spotify:track:72WZtWs6V7uu3aMgMmEkYe
#
#                                 Track Name  \
# 0  Justified & Ancient - Stand by the Jams
# 1          I Know You Want Me (Calle Ocho)
# 2       From the Bottom of My Broken Heart
# 3         Apeman - 2014 Remastered Version
# 4       You Can't Always Get What You Want
#
#                            Artist URI(s)      Artist Name(s)  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                               Album URI  \
# ...

# %%
# df.columns

# %%
df.info()
## Out of 35 columns, 17 columns as Numerical, 17 are string/object and 1 column is boolean
## By glancing it we know column "Album Release Date" should be date as the name says but it is currently Object type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Track URI             9999 non-null   object
#  1   Track Name            9998 non-null   object
#  2   Artist URI(s)         9997 non-null   object
#  3   Artist Name(s)        9998 non-null   object
#  4   Album URI             9997 non-null   object
#  5   Album Name            9998 non-null   object
#  6   Album Artist URI(s)   9997 non-null   object
#  7   Album Artist Name(s)  9997 non-null   object
#  8   Album Release Date    9997 non-null   object
#  9   Album Image URL       9995 non-null   object
#  10  Disc Number           9999 non-null   int64
#  11  Track Number          9999 non-null   int64
#  12  Track Duration (ms)   9999 non-null   int64
#  13  Track Preview URL     7102 non-null   object
#  14  Explicit              9999 non-null   bool
# ...

# %%
# Basic statistics of numeric columns
numeric_stats = df.describe()
numeric_stats
# Out:
#        Disc Number  Track Number  Track Duration (ms)   Popularity  \
# count  9999.000000   9999.000000         9.999000e+03  9999.000000
# mean      1.035104      4.957096         2.248150e+05    37.624662
# std       0.327856      5.502810         5.410012e+04    29.460808
# min       0.000000      0.000000         0.000000e+00     0.000000
# 25%       1.000000      1.000000         1.925795e+05     0.000000
# 50%       1.000000      3.000000         2.199060e+05    42.000000
# 75%       1.000000      7.000000         2.502600e+05    64.000000
# max      15.000000     93.000000         1.561133e+06    98.000000
#
#        Danceability       Energy          Key     Loudness         Mode  \
# count   9997.000000  9997.000000  9997.000000  9997.000000  9997.000000
# mean       0.607925     0.683281     5.167750    -7.269217     0.698410
# std        0.145869     0.191131     3.578392     3.281731     0.458971
# min        0.000000     0.000020     0.000000   -29.368000     0.000000
# ...

# %%
# Columns with missing values and their counts
missing_values = (df.isnull().sum()/len(df))*100
print(missing_values)
# Out:
# Track URI                 0.000000
# Track Name                0.010001
# Artist URI(s)             0.020002
# Artist Name(s)            0.010001
# Album URI                 0.020002
# Album Name                0.010001
# Album Artist URI(s)       0.020002
# Album Artist Name(s)      0.020002
# Album Release Date        0.020002
# Album Image URL           0.040004
# Disc Number               0.000000
# Track Number              0.000000
# Track Duration (ms)       0.000000
# Track Preview URL        28.972897
# Explicit                  0.000000
# Popularity                0.000000
# ISRC                      0.030003
# Added By                  0.000000
# Added At                  0.000000
# Artist Genres             5.500550
# Danceability              0.020002
# Energy                    0.020002
# Key                       0.020002
# Loudness                  0.020002
# Mode                      0.020002
# Speechiness               0.020002
# Acousticness              0.020002
# ...

# %%
df.shape
print(f'This dataset has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# This dataset has 9999 rows and 35 columns

# %%
print(f"This dataset has {df[df.duplicated(keep='first')].shape[0]} duplicate rows")
# Out:
# This dataset has 48 duplicate rows

# %%
# Finding duplicate rows
duplicate_rows = df[df.duplicated(keep='first')]

# Number of duplicate rows
num_duplicates = duplicate_rows.shape[0]

# Displaying the duplicate rows
print(f"Number of duplicate rows: {num_duplicates}")
# duplicate_rows
# Out:
# Number of duplicate rows: 48

# %%
df.drop_duplicates(keep='first', inplace=True)#data cleaning

# %%
((9999-df.shape[0])/9999)*100
# Out:
# 0.4800480048004801

# %%
# H/w Task
# Heatmap
# fillna
# replace

# %%
# To calculate the mean popularity of songs with the same track name and artist name

aggregated_df = df.groupby(['Track Name','Artist Name(s)'])['Popularity'].mean().reset_index()
aggregated_df
# Out:
#                                          Track Name  \
# 0                    ! (The Song Formerly Known As)
# 1                  "The Take Over, The Breaks Over"
# 2                                        #Beautiful
# 3                                           #SELFIE
# 4                   #WHERESTHELOVE - Charity Single
# ...                                             ...
# 8893  willow - dancing witch version (Elvira remix)
# 8894                              wish you were gay
# 8895                                        working
# 8896                             you broke me first
# 8897      you broke me first - Luca Schreiner Remix
#
#                   Artist Name(s)  Popularity
# 0                   Regurgitator        48.0
# 1                   Fall Out Boy         0.0
# 2           Mariah Carey, Miguel        23.5
# 3               The Chainsmokers         0.0
# 4     Black Eyed Peas, The World         0.0
# ...                          ...         ...
# ...

# %%
aggregated_df.sort_values(by='Popularity',ascending=False)
# Out:
#                                              Track Name  \
# 8890                                            vampire
# 1580                                  Cupid - Twin Ver.
# 3628                                    I'm Good (Blue)
# 3261                                    I Ain't Worried
# 1613            Dance The Night (From Barbie The Album)
# ...                                                 ...
# 1894         Don't Stop Movin' - Paul Morrell Radio Mix
# 6182                                             S.O.S.
# 1893                                  Don't Stop Movin'
# 1885                                         Don't Stop
# 4449  Listen To What The Man Said - 1993 Digital Rem...
#
#                 Artist Name(s)  Popularity
# 8890            Olivia Rodrigo        98.0
# 1580               FIFTY FIFTY        97.0
# 3628  David Guetta, Bebe Rexha        95.0
# 3261               OneRepublic        95.0
# 1613                  Dua Lipa        95.0
# ...

# %%
aggregated_df.sort_values(by='Popularity',ascending=False).head().plot(kind='bar',
                                                                      x = 'Artist Name(s)',
                                                                      y = 'Popularity',title = 'Top 5 Artist by Popularity')
plt.show()

# %%
# Get the number of unique values in each column
unique_values_count = df.nunique()

unique_values_count
# Out:
# Track URI               9951
# Track Name              8258
# Artist URI(s)           4134
# Artist Name(s)          4129
# Album URI               7462
# Album Name              6636
# Album Artist URI(s)     3298
# Album Artist Name(s)    3294
# Album Release Date      3332
# Album Image URL         7460
# Disc Number               10
# Track Number              57
# Track Duration (ms)     7320
# Track Preview URL       6889
# Explicit                   2
# Popularity                99
# ISRC                    8948
# Added By                   1
# Added At                 609
# Artist Genres           2815
# Danceability             779
# Energy                   876
# Key                       12
# Loudness                6329
# Mode                       2
# Speechiness             1059
# Acousticness            2746
# Instrumentalness        3028
# Liveness                1361
# Valence                  994
# Tempo                   8621
# Time Signature             5
# ...

# %% [markdown]
# # Visualization and Distribution

# %%
# Distribution of Popularity
plt.figure(figsize=(6, 4))
sns.histplot(df['Popularity'], kde=True)


plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('all_findings_images/Distribution of Popularity.png',dpi = 1000)
plt.show()

# %%
sns.histplot(df['Danceability'], kde=True)
plt.title('Distribution of Danceability')
plt.tight_layout()
plt.savefig('all_findings_images/Distribution of Danceability.png',dpi = 1000)
plt.show()

# %%
pd.to_datetime(df['Album Release Date'], errors='coerce')
# Out:
# 0      1992-08-03
# 1      2009-10-23
# 2      1999-01-12
# 3      2014-10-20
# 4      1969-12-05
#           ...
# 9994   2022-06-17
# 9995   2005-10-24
# 9996   2000-08-14
# 9997   2023-01-06
# 9998   2023-05-19
# Name: Album Release Date, Length: 9951, dtype: datetime64[ns]

# %%
# # Convert the 'Album Release Date' column to datetime
# Filter out rows with invalid dates in 'Album Release Date'
df['Album Release Date'] = pd.to_datetime(df['Album Release Date'], errors='coerce')

# Drop rows with invalid dates (NaT) from the DataFrame
df.dropna(subset=['Album Release Date'], inplace=True)


# # Extract the year from the release date
df['Release Year'] = df['Album Release Date'].dt.year

# # Selecting relevant columns for the plot: Release Year and Popularity
data_for_boxplot = df[['Release Year', 'Popularity']]

# # Handle missing values in the 'Artist Genres' column
data_for_boxplot['Release Year'].fillna('Unknown', inplace=True)

# # Create the boxplot
plt.figure(figsize=(12, 5))

sns.boxplot(data=data_for_boxplot, x='Release Year', y='Popularity',hue='Release Year')
plt.xticks(rotation=90)
plt.yticks(range(-50,200,50))
plt.title('Boxplot of Popularity by Release Year')
plt.tight_layout()


from datetime import datetime
date = datetime.now()
date = str(date).replace('-','_').replace(':','_').replace('.','_')

plt.savefig(f'all_findings_images/Boxplot of Popularity by Release Year {date}.png',dpi = 1000)
plt.show()

# %%
#remove outliers

# %%
# Distribution of Track Durations
plt.figure(figsize=(6, 4))

sns.histplot(df['Track Duration (ms)'] / 1000, bins=30, kde=True)

plt.title('Distribution of Track Durations')
plt.xlabel('Track Duration (seconds)')
plt.ylabel('Count')

date = datetime.now()
date = str(date).replace('-','_').replace(':','_').replace('.','_')
plt.tight_layout()

plt.savefig(f'all_findings_images/Distribution of Track Durations {date}.png',dpi = 1000)
plt.show()

# %%
 df['Album Name'].value_counts().head(10)
# Out:
# Album Name
# Greatest Hits                        80
# Best Of                              17
# Celebration (double disc version)    15
# Purpose (Deluxe)                     15
# The Very Best Of                     12
# Greatest                             12
# The Essential                        11
# The Greatest Hits                    11
# 21                                   11
# Anthology                            11
# Name: count, dtype: int64

# %%
df['Album Name'].value_counts().nlargest(10).values
# Out:
# array([80, 17, 15, 15, 12, 12, 11, 11, 11, 11], dtype=int64)

# %%
# Top 10 Albums with Most Songs

top_albums = df['Album Name'].value_counts().nlargest(10)
plt.figure(figsize=(6, 4))

ax = sns.barplot(x=top_albums.index, y=top_albums.values,palette=sns.color_palette('rainbow',len(top_albums)))

plt.title('Top 10 Albums with Most Songs')
plt.xlabel('Album Name')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45, ha='right')

for i in ax.containers:
    plt.bar_label(i)
plt.show()

# %% [markdown]
# ### 	Who has the highest popularity score?
# ### 	Who are the top ten most popular artists based on Spotify's popularity score?

# %%
df['Artist Name(s)'].value_counts().head(10)
# Out:
# Artist Name(s)
# Taylor Swift          48
# Ed Sheeran            39
# Madonna               39
# Elvis Presley         38
# U2                    38
# P!nk                  38
# The Beatles           37
# The Rolling Stones    33
# Elton John            27
# Bee Gees              27
# Name: count, dtype: int64

# %%
# Top 10 artists with the most number of songs
top_artists = df['Artist Name(s)'].value_counts().nlargest(10)

plt.figure(figsize=(6,4))
ax = sns.barplot(x=top_artists.index, y=top_artists.values,palette=sns.color_palette('rainbow',len(top_artists)))
plt.title('Top 10 Artists with Most Songs')
plt.xlabel('Artist Name')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45, ha='right')

for i in ax.containers:
    plt.bar_label(i)
plt.show()

# %%
# df.groupby('Artist Name(s)')['Artist Name(s)'].count().sort_values(ascending=False)[:20].plot(kind='bar',
#                                                                                               color = sns.color_palette('magma',20))

# %%
# green_color = ['green']*5
# gray_color = ['gray']*15

# color = green_color + gray_color
# color

# %%
#### Top 20 Artist by number of songs released
top20_artists = df.groupby(by='Artist Name(s)')['Artist Name(s)'].count().sort_values(ascending=False)[:20]

colors = ['red'] * 5 + ['#B8FCB3'] * (len(top20_artists) - 5)

ax = top20_artists.plot(kind='bar', color=colors)  # Highlight first 5 bars in green
plt.title("Top 20 Artists releasing song on Spotify",color='gray',fontweight='bold')
plt.xlabel("Artists")
plt.xticks(rotation=75)
plt.yticks(range(0,70,10))
plt.ylabel("Number of Songs released by Artists")


for i in ax.containers:
    plt.bar_label(i,padding = 5)
plt.show()

## We have highlighted top 5 singers who created approx 40 or more songs ( Taylor Shift,Pink,Elvis Presley, Ed Sheeran,U2)

# %%
# df['Artist Genres'].nunique()

# %%
# Count of unique genres in the 'Artist Genres' column
artist_genres_count = df['Artist Genres'].nunique()

print(f"Number of unique artist genres: {artist_genres_count}")
# Out:
# Number of unique artist genres: 2613

# %%
tem = df['Release Year'].value_counts().reset_index()
tem[tem['Release Year']<2016]
tem[tem['Release Year']>=2016]
# Out:
#     Release Year  count
# 3           2016    377
# 6           2017    347
# 10          2018    261
# 11          2020    256
# 14          2019    211
# 15          2021    207
# 37          2022     60
# 58          2023     33

# %%
#### Songs released per year
df['ReleaseYear'] = df['Album Release Date'].dt.year
songs_per_year=df['ReleaseYear'].value_counts().reset_index(drop=False).rename(columns={'index':'ReleaseYear','count':'#Songs'})
plt.figure(figsize=(5,5))

sns.lineplot(data=songs_per_year[songs_per_year['ReleaseYear']<2016],x='ReleaseYear',y='#Songs',color='green')

sns.lineplot(data=songs_per_year[songs_per_year['ReleaseYear']>=2015],x='ReleaseYear',y='#Songs',color='red')

plt.title("Number of songs released per year",loc='left',color='gray',fontweight='bold')
plt.show()

## Growth of song every year is quite good but after 2015 the growth stopped and it started to fall down. Same is highlighted in the visualization

# %%
df['Track Duration (ms)']/(1000*60)
# Out:
# 0       3.604500
# 1       3.952000
# 2       5.208883
# 3       3.890000
# 4       7.478667
#           ...
# 9994    2.763333
# 9995    2.944000
# 9996    3.793650
# 9997    2.557367
# 9998    2.771100
# Name: Track Duration (ms), Length: 8582, dtype: float64

# %%
#### Long Duration songs are more popular?
df['Track Duration Minute'] = df['Track Duration (ms)']/60000  ##First convert the Duration from Millisecond to minute

sns.scatterplot(data=df,y='Popularity',x='Track Duration Minute')
plt.title("Is Longer songs are more popular?",loc='left',color='gray',fontweight='bold')
plt.axvline(5,color='r')
plt.axvline(2,color='r')

plt.show()
## Most of the songs are of around 5 minutes, There are some unpopular song as well whose popularity is 0
## It is hard to tell if short/long duration songs are more popular

# %%
sns.scatterplot(data=df,x='ReleaseYear',y='Loudness')
plt.title("Are musics turning louder over the year?",loc='left',color='gray',fontweight='bold')
plt.show()
## We do see a upward trend over the year.

# %%
sns.scatterplot(data=df,x='Energy',y='Loudness')
plt.title("Is there any relationship between energy and loudness?",loc='left',color='gray',fontweight='bold')
plt.show()
## We do see a linear relationship between these 2 columns

# %% [markdown]
# ### 	Can we identify any trends in album releases over the years (e.g., are there more albums in recent years)?

# %%
#### Creating new column  ReleaseYearFlag which flag if the song was released Before 2000 or after
df['ReleaseYearFlag']=np.where(df['ReleaseYear']<2000,'Before2000','After2000')

# %%
df['ReleaseYearFlag'].value_counts()
# Out:
# ReleaseYearFlag
# After2000     6086
# Before2000    2496
# Name: count, dtype: int64

# %%
##### Comparing how music flavour changed before and after year 2000
cols=['Popularity','Energy','Loudness','Mode','Speechiness']
plt.figure(figsize=(25,3))

row=1
col=len(cols)*2


k=0
for i in range(1,col,2):
    plt.subplot(row,col,i)
    sns.boxplot(data=df,y=cols[k],x='ReleaseYearFlag')
    k+=1                   
plt.show()


print("\n")


#### Popularity declined after 2000
#### Energy in the new song increased
#### Loudness increased in new songs
#### Mode turned ON in new songs
#### Speechiness increased in new songs
#### Acousticness decreased in newer songs
#### Valence descreased in new songs
#### Tempand track duration remained as it is
#### It is possible that the stated reasons play a role in the present downtrend of newer song popularity.

# %%
cols=['Acousticness','Instrumentalness','Liveness','Valence','Tempo','Track Duration Minute']

plt.figure(figsize=(30,3))
row=1
col=len(cols)*2
k=0
for i in range(1,col,2):
    plt.subplot(row,col,i)
    sns.boxplot(data=df,y=cols[k],x='ReleaseYearFlag')
    k+=1                   
plt.show()

# %% [markdown]
# ### 	What are the distributions of key audio features like danceability, energy, and valence?

# %%
# Selecting relevant features for visualization
selected_features = df[['Danceability', 'Energy', 'Acousticness', 'Instrumentalness', 'Valence']]

# Violin plots for selected track features
plt.figure(figsize=(6, 4))

# sns.boxplot(data=selected_features, palette='viridis')
sns.violinplot(data=selected_features, palette='viridis', inner='quartile')
plt.title('Distribution of Track Features')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 	What are the most common music genres in the dataset, and how do they correlate with popularity?

# %%
df['Artist Genres'].value_counts().head(10)
# Out:
# Artist Genres
# dance pop,pop                                  238
# pop                                            220
# australian rock                                173
# australian pop,australian talent show           80
# australian pop                                  66
# australian pop,australian rock                  59
# australian alternative rock,australian rock     57
# rock-and-roll,rockabilly                        45
# pop,singer-songwriter pop,uk pop                39
# dance pop,pop,pop rap                           39
# Name: count, dtype: int64

# %%
# Top 10 most common artist genres
top_artist_genres = df['Artist Genres'].value_counts().nlargest(10)
plt.figure(figsize=(6, 4))

sns.barplot(x=top_artist_genres.index, y=top_artist_genres.values,palette=sns.color_palette('rainbow',len(top_artist_genres)))

plt.title('Top 10 Most Common Artist Genres')
plt.xlabel('Artist Genres')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### 	How many explicit tracks are in the dataset, and do they differ in terms of audio features?

# %%
df['Explicit'].value_counts()
# Out:
# Explicit
# False    8093
# True      489
# Name: count, dtype: int64

# %%
# Explicit vs. Non-Explicit Songs
plt.figure(figsize=(6, 6))
df['Explicit'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['#8AFF33', '#F79C7F'])
plt.title('Percentage of Explicit vs. Non-Explicit Songs')

plt.ylabel('')
plt.show()

# %%
lbl = df['Explicit'].value_counts().index
value = df['Explicit'].value_counts().values
plt.pie(x = value,colors=['g','r'],labels=lbl,autopct='%1.1f%%',pctdistance=0.5)
plt.pie(x = (1,),radius=0.7,colors='w')
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
# #Popularity Analysis:
# import seaborn as sns
# import matplotlib.pyplot as plt

# sns.histplot(df['Popularity'], kde=True)
# plt.title('Distribution of Song Popularity')
# plt.show()

# %%
# # Danceability Analysis:
# sns.histplot(df['Danceability'], kde=True)
# plt.title('Distribution of Danceability')
# plt.show()

# %%
# Energy Analysis:
sns.histplot(df['Energy'], kde=True)
plt.title('Distribution of Energy')
plt.show()

# %%
# Valence Analysis:
sns.histplot(df['Valence'], kde=True)
plt.title('Distribution of Valence')
plt.show()

# %%
# Release Year Analysis:
# Assuming 'Album Release Date' is in datetime format
# df['Album Release Date'] = pd.to_datetime(df['Album Release Date'])
sns.histplot(df['Album Release Date'].dt.year, kde=True)
plt.title('Distribution of Release Years')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Popularity vs. Danceability:
sns.scatterplot(x='Danceability', y='Popularity', data=df)
plt.title('Popularity vs. Danceability')
plt.xlabel('Danceability Score')
plt.ylabel('Popularity Score')
plt.show()
# No such relationship found b/w Popularity vs. Danceability

# %%
#Key vs. Mode:
sns.countplot(x='Key', hue='Mode', data=df)
plt.title('Key vs. Mode')
plt.xlabel('Key')
plt.show()
# No such relationship found

# %% [markdown]
# # Multivariate Analysis

# %%
# df.corr(numeric_only=True)
# df['Album Genres']|

# %%
# Correlation Heatmap for numeric columns
plt.figure(figsize=(12, 10))
sns.heatmap(df.drop('Album Genres',axis = 1).corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Popularity, Danceability, and Energy:
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 8),dpi=100)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Danceability'], df['Energy'], df['Popularity'])

ax.zaxis.labelpad=1
ax.set_xlabel('Danceability')
ax.set_ylabel('Energy')
ax.set_zlabel('Popularity')

ax.set_title('Popularity, Danceability, and Energy')
plt.show()

# %%
# df['Artist Genres'].str.split(',').apply(lambda x: len(x) if type(x)==list else x).mean()

# %% [markdown]
# # <u>FINDINGS & INSIGHTS</u>

# %%
# df.columns

# %%
df[df['Popularity']==df['Popularity'].max()]
# Out:
#                                  Track URI Track Name  \
# 2428  spotify:track:3k79jB4aGmMDUQzEwa46Rz    vampire
#
#                               Artist URI(s)  Artist Name(s)  \
# 2428  spotify:artist:1McMsnEElThX1knmY4oliG  Olivia Rodrigo
#
#                                  Album URI Album Name  \
# 2428  spotify:album:5kqfR7EuGbyp8x27Pr1kY9    vampire
#
#                         Album Artist URI(s) Album Artist Name(s)  \
# 2428  spotify:artist:1McMsnEElThX1knmY4oliG       Olivia Rodrigo
#
#      Album Release Date                                    Album Image URL  \
# 2428         2023-06-30  https://i.scdn.co/image/ab67616d0000b2731e5e75...
#
#       ...  Valence    Tempo  Time Signature Album Genres              Label  \
# 2428  ...    0.322  137.827             4.0          NaN  Olivia Rodrigo PS
#
#                                              Copyrights Release Year  \
# 2428  C © 2023 Olivia Rodrigo, under exclusive licen...         2023
#
# ...

# %%
# df[df['Artist Name(s)'] == 'Taylor Swift']['Popularity'].mean()

# %%
# df.groupby('Artist Name(s)')['Popularity'].max().sort_values(ascending=False)
# Out:
# Artist Name(s)
# Olivia Rodrigo               98
# FIFTY FIFTY                  97
# Miley Cyrus                  96
# Dua Lipa                     95
# David Guetta, Bebe Rexha     95
#                              ..
# Olly Murs, Flo Rida           0
# Olly Murs, Louisa Johnson     0
# Olly Murs, Travie McCoy       0
# Otto Knows                    0
# will.i.am, Nicki Minaj        0
# Name: Popularity, Length: 3710, dtype: int64

# %% [markdown]
# #### 1. Who has the highest popularity score?
# - Olivia Rodrigo has the highest popularity score(98).
#
# #### 2. Who are the top ten most popular artists based on Spotify's popularity score?
# - Taylor Swift, Pink, Elvis Presly, Ed Sheeran, Madonna, U2, The beatles, The rolling stones, INXS, Bee Gees are top 10 artists.
#
# #### 3. Can we identify any trends in album releases over the years (e.g., are there more albums in recent years)?
# - Yes, there has been an increase of 22% in album releases over the years.
# #### 4. What are the distributions of key audio features like danceability, energy, and valence?
# - Danceability (0.5), Energy(0.25), Valence(0.5)
#
# #### 5. What are the most common music genres in the dataset, and how do they correlate with popularity?
# - Rap, Latin, Pop, Country, R&B, Rock, Electronic, Jazz, Blues, Classical are most common music genres but it is worth noting that the popularity of a genre is not necessarily with its quality or artistic merit, but with its ability to resonate with larger audience.
#
# #### 6. How many explicit tracks are in the dataset, and do they differ in terms of audio features?
# - 6% tracks in the dataset are explicit but there is not much significant difference in terms of audio features.
#
# #### 7. Which artist has the largest discography in terms of the number of tracks?
# - Drake has the largest discography in terms of the number of tracks.
#
# #### 8. Can we observe trends in track popularity over time, and are certain months associated with more popular releases?
# - Yes, there is significant trends in track popularity over time, but it depends on the genre. No certainty in months can be observed.
#
# #### 9. What are the most common time signatures, and do they vary by genre?
# - 4/4 is the most common time signature followed by 3/4 and 6/8 time signatures. More than a third of songs are based on these signatures.
#
# #### 10. Is there a difference in audio features between instrumental and vocal tracks?
# - Yes, difference is there in audio features. The closer the value to 1.0 the likelihood of a track being vocal is high.
#
# #### 11. How have audio features like danceability and tempo evolved over time?
# - Yes, danceability and tempo of tracks has evolved over time. Most popular songs have higher danceability and tempo values.
#
# #### 12. What is the distribution of track durations, and do longer tracks tend to be more popular?
# - The mean duration of tracks is 3 min and 44 sec. Popularity of song is not based on tracks.
#
#
# #### 13. Can we analyze user interaction data, such as the number of times a track has been saved or liked?
# - Yes, we can find the number of times a track has been saved or liked.
#
# #### 14. How many unique genres are associated with each artist, and is there a correlation between genre diversity and popularity?
# - On average 4 unique genres are associated with each artist. Yes, correlation exists.
#
# #### 15. Do certain music genres gain or lose popularity over the years?
# - Yes, old genres popularity is declining over time.
#
# #### 16. Is there a relationship between liveness and popularity, and do live tracks tend to be longer or shorter?
# - Yes, a value above 0.8 provides a strong likelihood that a tack is live. Length is short.
#
# #### 17. Are there trends in tempo over the decades, and do certain genres have characteristic tempos?
# - Yes, dance music has a higher tempo than other genres and has been growing.
#
# #### 18. Do certain music genres have preferred time signatures, and how does this affect the feel of the music?
# - 4/4 time signature is widely used in rock, country, blues, funk, and pop music.
# - 3/4 time signature is commonly used in waltzes, minuets, scherzi, country and western ballads, R&B, and pop music.
# - 6/8 time signature is used in double jigs, polkas, sega, salegy, tarantella, marches, barcarolles, Irish jigs, loures, and some rock music.
#
# #### 19. Has the proportion of explicit tracks changed over time, and are they more common in specific genres?
# - Yes, it depends on the artist.
#
# #### 20. What are the most common record labels, and do tracks from specific labels tend to have distinct audio characteristics?
# - Sony BMG, Universal Music, Warner Music, EMI and Merlin are the most common labels.

# %% [markdown]
# # <u>CONCLUSIONS</u>
#
# #### The Spotify Top 10000 songs dataset is a large and diverse dataset of popular songs.Exploratory data analysis (EDA) revealed a number of interesting insights about the dataset, including:

# %%
df.groupby('Release Year')['Track Duration (ms)'].mean().plot()
# Out:
# <Axes: xlabel='Release Year'>

# %% [markdown]
# - Pop is the most popular genre, followed by rock and hip hop.
# - Danceability and energy are the most important features for song popularity.
# - There is a strong correlation between danceability and energy, and between acousticness and valence.
# - The average song duration has been increasing over time.
# - The most popular songs are released by a relatively small number of artists.
#
#
# ``Overall, the Spotify Top 10000 songs dataset is a valuable resource for understanding the music industry and the preferences of music listeners. The insights from EDA can be used to develop new music recommendation systems, to create playlists that are tailored to specific tastes, and to understand the trends in popular music.``
#
# ##### Here are some specific conclusions from the EDA:
# - Pop is the most popular genre, followed by rock and hip hop. This finding is consistent with other studies of popular music.
#
# - Danceability and energy are the most important features for song popularity. This suggests that people are drawn to songs that are upbeat and danceable.
#
# - There is a strong correlation between danceability and energy, and between acousticness and valence. This means that songs that are danceable are also likely to be high in energy, and songs that are acoustic are likely to be high in valence (positive emotion).
#
# - The average song duration has been increasing over time. This is likely due to the increasing popularity of streaming services, which have made it easier for people to listen to long songs.
#
# - The most popular songs are released by a relatively small number of artists. This suggests that the music industry is becoming increasingly concentrated.
#
#
# **These conclusions can be used to develop new music recommendation systems, to create playlists
# that are tailored to specific tastes, and to understand the trends in popular music. For example, a
# music recommendation system could use the finding that danceability and energy are the most
# important features for song popularity to recommend songs to users that are likely to be upbeat and
# danceable. Similarly, a playlist creator could use the finding that acoustic songs are likely to be
# high in valence to create a playlist of relaxing and calming songs. Finally, the finding that the most
# popular songs are released by a relatively small number of artists could be used to identify
# emerging artists who are likely to become popular in the future.**

# %%
# pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
data = 'ajay ajay ajay ravi mohan ajay mohan karan mohan'

plt.imshow(WordCloud(width = 800, height = 800).generate(data))

# %%
data = ' '.join(df['Album Artist Name(s)'])
plt.figure(figsize=(10,10),dpi=1000)
plt.imshow(WordCloud(width = 1200, height = 1200).generate(data))
